# %% [markdown]
# Hello

# %%
pip install OpenAI
# Out:
# Requirement already satisfied: OpenAI in /usr/local/lib/python3.12/dist-packages (2.43.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from OpenAI) (4.14.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from OpenAI) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from OpenAI) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from OpenAI) (0.15.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from OpenAI) (2.13.4)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from OpenAI) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.12/dist-packages (from OpenAI) (4.67.3)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.12/dist-packages (from OpenAI) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->OpenAI) (3.18)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->OpenAI) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->OpenAI) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->OpenAI) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->OpenAI) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->OpenAI) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->OpenAI) (0.4.2)

# %%
from anthropic import Anthropic

# %%
from openai import OpenAI
from google.colab import userdata

# %%
from pprint import pprint

def print_response(response):
  print(f"ResponceId: {response.id}")
  print(f"Input tokens: {response.usage.input_tokens} ({response.usage.input_tokens_details.cached_tokens} cched) | Output tokens: {response.usage.output_tokens} ({response.usage.output_tokens_details.reasoning_tokens} reasoning)")
  pprint(response.output)

  print()
  print(f"{'='*20} [Text] {'='*20}")
  print(response.text)
  print()
  print(f"{'='*20} [Finish Reason] {'='*20}")
  pprint(response.output_text)

# %%
api_Key = userdata.get("AIKey")

# %%
client = OpenAI(api_key=api_Key)

response = client.responses.create(
    model="gpt-5-nano",
    input="Write a short bedtime story about a unicorn.",
    instructions="exactly 3 sentencises, max 50 words"
)
# Out:
# In the quiet valley, a gentle unicorn named Luma watched the stars twinkle as the moon rose. She trotted softly to the silver stream and whispered a lullaby to all the sleepy creatures. When the night grew still, Luma drifted off beneath a blanket of firefly light, dreaming of dawn.

# %%
print_response(response)
# Out:
# ResponceId: resp_0e171bad23207d4c006a50ca335c64819cb2f68b6b1be0547f
# Input tokens: 31 (0 cched) | Output tokens: 521 (448 reasoning)
# [ResponseReasoningItem(id='rs_0e171bad23207d4c006a50ca33f8f8819c87c9431a59c4e538', summary=[], type='reasoning', content=[], encrypted_content=None, status=None),
#  ResponseOutputMessage(id='msg_0e171bad23207d4c006a50ca3760c8819ca5a2d213727ab955', content=[ResponseOutputText(annotations=[], text='In the quiet valley, a gentle unicorn named Luma watched the stars twinkle as the moon rose. She trotted softly to the silver stream and whispered a lullaby to all the sleepy creatures. When the night grew still, Luma drifted off beneath a blanket of firefly light, dreaming of dawn.', type='output_text', logprobs=[])], role='assistant', status='completed', type='message', phase=None)]
#
# ==================== [Text] ====================
# ResponseTextConfig(format=ResponseFormatText(type='text'), verbosity='medium')
#
# ==================== [Finish Reason] ====================
# ('In the quiet valley, a gentle unicorn named Luma watched the stars twinkle '
#  'as the moon rose. She trotted softly to the silver stream and whispered a '
#  'lullaby to all the sleepy creatures. When the night grew still, Luma drifted '
#  'off beneath a blanket of firefly light, dreaming of dawn.')

# %%
second_response = client.responses.create(
    model="gpt-5-nano",
    input="The unicorn meets a bear and they go for walk. What happens next?",
    previous_response_id=response.id
)

# %%
print_response(second_response)
# Out:
# ResponceId: resp_0e171bad23207d4c006a50d9cefd9c819c8a476f17c361ec4b
# Input tokens: 103 (0 cched) | Output tokens: 1918 (1600 reasoning)
# [ResponseReasoningItem(id='rs_0e171bad23207d4c006a50d9cfb68c819ca174670d60d7cfa8', summary=[], type='reasoning', content=[], encrypted_content=None, status=None),
#  ResponseOutputMessage(id='msg_0e171bad23207d4c006a50d9dc1b74819cb0fcb74b164f1ebd', content=[ResponseOutputText(annotations=[], text='In the soft hush of night, Luma dreamed of a bear named Bristle who stepped from the shadow like a gentle breeze. Bristle wore a friendly smile and carried piney stories in his heart. “Shall we take a walk?” he asked, and the two set off along a path lit by moonflowers and fireflies.\n\nThey wandered beside a singing brook, where water sang about distant stars. Bristle showed Luma a hollow tree where a family of hedgehogs slept soundly; with a whisper of magic, Luma’s horn cast a warm glow to light their path without waking them. They paused to share a cool berry snack and listened to the forest’s night chorus—the crickets tapping a tiny rhythm, the owls moving like sentinels on the branch above.\n\nAs they climbed a mossy hill, Bristle spoke softly about patience and courage, and Luma felt a new kind of bravery blooming inside her. The world seemed to glow a little brighter, as if the forest itself was smiling at their friendship. When dawn began to tiptoe across the sky, they found their way back to the stream, the dream fading yet tender in Luma’s heart.\n\nShe woke just as the first light brushed the valley, warm with the memory of a peaceful walk with a bear who became a friend.', type='output_text', logprobs=[])], role='assistant', status='completed', type='message', phase=None)]
#
# ==================== [Text] ====================
# ResponseTextConfig(format=ResponseFormatText(type='text'), verbosity='medium')
#
# ==================== [Finish Reason] ====================
# ('In the soft hush of night, Luma dreamed of a bear named Bristle who stepped '
#  'from the shadow like a gentle breeze. Bristle wore a friendly smile and '
#  'carried piney stories in his heart. “Shall we take a walk?” he asked, and '
#  'the two set off along a path lit by moonflowers and fireflies.\n'
#  '\n'
#  'They wandered beside a singing brook, where water sang about distant stars. '
#  'Bristle showed Luma a hollow tree where a family of hedgehogs slept soundly; '
#  'with a whisper of magic, Luma’s horn cast a warm glow to light their path '
#  'without waking them. They paused to share a cool berry snack and listened to '
#  'the forest’s night chorus—the crickets tapping a tiny rhythm, the owls '
#  'moving like sentinels on the branch above.\n'
#  '\n'
#  'As they climbed a mossy hill, Bristle spoke softly about patience and '
#  'courage, and Luma felt a new kind of bravery blooming inside her. The world '
#  'seemed to glow a little brighter, as if the forest itself was smiling at '
#  'their friendship. When dawn began to tiptoe across the sky, they found their '
#  'way back to the stream, the dream fading yet tender in Luma’s heart.\n'
#  '\n'
#  'She woke just as the first light brushed the valley, warm with the memory of '
#  'a peaceful walk with a bear who became a friend.')

# %%
with client.responses.stream(
    model="gpt-5-nano",
    input="Tell me more about RAG in contect of AI",
    instructions="Short answer 3 sentances on ENG and 3 on BG"
)as stream:
  for event in stream:
    if event.type == 'response.output_text.delta':
      print(event.delta, end='', flush=True)
    print()

  stream_response = stream.get_final_response()
# Out:
# English
# :
#
# Retr
# ieval
# -Aug
# mented
#  Generation
#  (
# R
# AG
# )
#  is
#  an
#  AI
#  approach
#  that
#  combines
#  text
#  retrieval
#  with
#  language
#  generation
#  to
#  produce
#  answers
#  using
#  both
#  a
#  generator
#  and
#  a
#  retr
# iever
# .
#  A
#  retr
# iever
#  fetch
# es
#  relevant
#  documents
#  or
#  passages
#  from
#  a
#  knowledge
#  base
# ,
#  which
#  are
#  then
#  fed
#  to
#  a
#  generator
#  (
# like
#  a
#  language
#  model
# )
#  to
#  produce
#  more
#  accurate
# ,
#  context
# -aware
#  outputs
# .
#  This
#  setup
#  helps
#  reduce
#  halluc
# inations
#  and
#  keeps
#  content
#  up
# -to
# -date
# ,
#  but
#  it
#  relies
#  on
#  a
#  high
# -quality
#  retrieval
#  corpus
#  and
#  adds
#  complexity
#  and
#  latency
# .
#
#
# Bul
# gar
# ian
# :
#
# R
# AG
#  (
# Retr
# ieval
# -Aug
# mented
#  Generation
# )
#  е
#  подход
#  в
#  И
# И
# ,
#  който
#  съ
# ч
# ета
# ва
#  т
# ър
# с
# ене
#  на
#  рел
# ев
# ант
# ни
#  докум
# енти
#  с
#  ген
# ери
# ране
#  на
#  текст
# .
#  Т
# ър
# са
# ч
# ката
#  изв
# лич
# а
#  рел
# ев
# ант
# ни
#  отк
# ъ
# си
#  от
#  база
#  дан
# ни
#  или
#  интернет
# ,
#  които
#  се
#  подав
# ат
#  на
#  генера
# тора
# ,
#  за
#  да
#  се
#  съ
# з
# да
# дат
#  по
# -то
# ч
# ни
#  и
#  конт
# екст
# но
#  съ
# образ
# ени
#  от
# говор
# и
# .
#  Пред
# им
# ств
# ата
#  включ
# ват
#  по
# -то
# ч
# ни
#  фак
# ти
#  и
#  акту
# ал
# ност
# ,
#  но
#  из
# иск
# ват
#  добре
#  под
# бра
# на
#  база
#  за
#  т
# ър
# с
# ене
#  и
#  могат
#  да
#  въ
# вед
# ат
#  доп
# ъл
# н
# ител
# на
#  лат
# ент
# ност
#  и
#  слож
# ност
# .

# %%
print_response(stream_response)
# Out:
# ResponceId: resp_0b50c9b14ddfb288006a50de37925c81a29ec78bd4fd9c65a5
# Input tokens: 34 (0 cched) | Output tokens: 1773 (1472 reasoning)
# [ResponseReasoningItem(id='rs_0b50c9b14ddfb288006a50de3834f481a29d8ed8dfc75aad4a', summary=[], type='reasoning', content=[], encrypted_content=None, status=None),
#  ParsedResponseOutputMessage[TypeVar](id='msg_0b50c9b14ddfb288006a50de43da0881a2a8d9319ccecd1313', content=[ParsedResponseOutputText[TypeVar](annotations=[], text='English:\nRetrieval-Augmented Generation (RAG) is an AI approach that combines text retrieval with language generation to produce answers using both a generator and a retriever. A retriever fetches relevant documents or passages from a knowledge base, which are then fed to a generator (like a language model) to produce more accurate, context-aware outputs. This setup helps reduce hallucinations and keeps content up-to-date, but it relies on a high-quality retrieval corpus and adds complexity and latency.\n\nBulgarian:\nRAG (Retrieval-Augmented Generation) е подход в ИИ, който съчетава търсене на релевантни документи с генериране на текст. Търсачката извлича релевантни откъси от база данни или интернет, които се подават на генератора, за да се създадат по-точни и контекстно съобразени отговори. Предимствата включват по-точни факти и актуалност, но изискват добре подбрана база за търсене и могат да въведат допълнителна латентност и сложност.', type='output_text', logprobs=[], parsed=None)], role='assistant', status='completed', type='message', phase=None)]
#
# ==================== [Text] ====================
# ResponseTextConfig(format=ResponseFormatText(type='text'), verbosity='medium')
#
# ==================== [Finish Reason] ====================
# ('English:\n'
#  'Retrieval-Augmented Generation (RAG) is an AI approach that combines text '
#  'retrieval with language generation to produce answers using both a generator '
#  'and a retriever. A retriever fetches relevant documents or passages from a '
#  'knowledge base, which are then fed to a generator (like a language model) to '
#  'produce more accurate, context-aware outputs. This setup helps reduce '
#  'hallucinations and keeps content up-to-date, but it relies on a high-quality '
#  'retrieval corpus and adds complexity and latency.\n'
#  '\n'
#  'Bulgarian:\n'
#  'RAG (Retrieval-Augmented Generation) е подход в ИИ, който съчетава търсене '
#  'на релевантни документи с генериране на текст. Търсачката извлича релевантни '
#  'откъси от база данни или интернет, които се подават на генератора, за да се '
#  'създадат по-точни и контекстно съобразени отговори. Предимствата включват '
#  'по-точни факти и актуалност, но изискват добре подбрана база за търсене и '
#  'могат да въведат допълнителна латентност и сложност.')
